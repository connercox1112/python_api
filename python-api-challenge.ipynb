# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 559

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "?q=" + city + "&appid=weather_api_key"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | iqaluit
# Processing Record 2 of Set 1 | port-aux-francais
# Processing Record 3 of Set 1 | brisas de zicatela
# Processing Record 4 of Set 1 | masterton
# Processing Record 5 of Set 1 | udachny
# Processing Record 6 of Set 1 | riachao das neves
# Processing Record 7 of Set 1 | grytviken
# Processing Record 8 of Set 1 | mahavelona
# Processing Record 9 of Set 1 | kerikeri
# Processing Record 10 of Set 1 | shalqar
# Processing Record 11 of Set 1 | klyuchi
# Processing Record 12 of Set 1 | invercargill
# Processing Record 13 of Set 1 | newman
# Processing Record 14 of Set 1 | happy valley-goose bay
# Processing Record 15 of Set 1 | lihue
# Processing Record 16 of Set 1 | bredasdorp
# Processing Record 17 of Set 1 | margaret river
# Processing Record 18 of Set 1 | urcos
# Processing Record 19 of Set 1 | colonia
# Processing Record 20 of Set 1 | tiksi
# Processing Record 21 of Set 1 | an nuhud
# Processing Record 22 of Set 1 | puerto natales
# Processing Record 23 of Set 1 | port saint john's
# Processing Record 24 of Set 1 | thompson
# Processing Record 25 of Set 1 | mwanza
# Processing Record 26 of Set 1 | fort st. john
# Processing Record 27 of Set 1 | adamstown
# Processing Record 28 of Set 1 | la passe
# Processing Record 29 of Set 1 | afaahiti
# Processing Record 30 of Set 1 | dunedin
# Processing Record 31 of Set 1 | jamestown
# Processing Record 32 of Set 1 | katima mulilo
# Processing Record 33 of Set 1 | lompoc
# Processing Record 34 of Set 1 | meulaboh
# Processing Record 35 of Set 1 | berezovyy
# Processing Record 36 of Set 1 | edinburgh of the seven seas
# Processing Record 37 of Set 1 | waitangi
# Processing Record 38 of Set 1 | bonthe
# Processing Record 39 of Set 1 | ta`u
# Processing Record 40 of Set 1 | albany
# Processing Record 41 of Set 1 | polyarnyye zori
# Processing Record 42 of Set 1 | vilyuchinsk
# Processing Record 43 of Set 1 | luancheng
# Processing Record 44 of Set 1 | piti village
# Processing Record 45 of Set 1 | riachao do jacuipe
# Processing Record 46 of Set 1 | hawaiian paradise park
# Processing Record 47 of Set 1 | irymple
# Processing Record 48 of Set 1 | hermanus
# Processing Record 49 of Set 1 | piacabucu
# Processing Record 50 of Set 1 | 'ohonua
# City not found. Skipping...
# Processing Record 0 of Set 2 | papatowai
# Processing Record 1 of Set 2 | taksimo
# Processing Record 2 of Set 2 | nova sintra
# Processing Record 3 of Set 2 | armyansk
# Processing Record 4 of Set 2 | pangody
# Processing Record 5 of Set 2 | blackmans bay
# Processing Record 6 of Set 2 | vila franca do campo
# Processing Record 7 of Set 2 | corn island
# Processing Record 8 of Set 2 | remire-montjoly
# Processing Record 9 of Set 2 | akropong
# Processing Record 10 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 11 of Set 2 | kodiak
# Processing Record 12 of Set 2 | antofagasta
# Processing Record 13 of Set 2 | flin flon
# Processing Record 14 of Set 2 | ushuaia
# Processing Record 15 of Set 2 | meadow lake
# Processing Record 16 of Set 2 | guerrero negro
# Processing Record 17 of Set 2 | waingapu
# Processing Record 18 of Set 2 | puerto ayora
# Processing Record 19 of Set 2 | anadyr
# Processing Record 20 of Set 2 | mount gambier
# Processing Record 21 of Set 2 | kapa'a
# Processing Record 22 of Set 2 | conception bay south
# Processing Record 23 of Set 2 | port moresby
# Processing Record 24 of Set 2 | ancud
# Processing Record 25 of Set 2 | mana
# Processing Record 26 of Set 2 | punta arenas
# Processing Record 27 of Set 2 | bilibino
# Processing Record 28 of Set 2 | pratapgarh
# Processing Record 29 of Set 2 | san patricio
# Processing Record 30 of Set 2 | kudahuvadhoo
# Processing Record 31 of Set 2 | krasnyy kholm
# Processing Record 32 of Set 2 | leninskoye
# Processing Record 33 of Set 2 | west island
# Processing Record 34 of Set 2 | hithadhoo
# Processing Record 35 of Set 2 | laascaanood
# Processing Record 36 of Set 2 | qaqortoq
# Processing Record 37 of Set 2 | nueva gerona
# Processing Record 38 of Set 2 | i-n-salah
# Processing Record 39 of Set 2 | molina
# Processing Record 40 of Set 2 | viru
# Processing Record 41 of Set 2 | yellowknife
# Processing Record 42 of Set 2 | cabo san lucas
# Processing Record 43 of Set 2 | hassi messaoud
# Processing Record 44 of Set 2 | hammerfest
# Processing Record 45 of Set 2 | tazovsky
# Processing Record 46 of Set 2 | bethel
# Processing Record 47 of Set 2 | murrells inlet
# Processing Record 48 of Set 2 | cranbrook
# Processing Record 49 of Set 2 | salinopolis
# Processing Record 0 of Set 3 | outapi
# City not found. Skipping...
# Processing Record 1 of Set 3 | tarinkot
# Processing Record 2 of Set 3 | villa hayes
# Processing Record 3 of Set 3 | port mathurin
# Processing Record 4 of Set 3 | gamba
# Processing Record 5 of Set 3 | cotusca
# Processing Record 6 of Set 3 | plastun
# Processing Record 7 of Set 3 | stanley
# Processing Record 8 of Set 3 | fale old settlement
# Processing Record 9 of Set 3 | longyearbyen
# Processing Record 10 of Set 3 | muravlenko
# Processing Record 11 of Set 3 | port hedland
# Processing Record 12 of Set 3 | yarmouth
# Processing Record 13 of Set 3 | kataragama
# City not found. Skipping...
# Processing Record 14 of Set 3 | rio grande
# Processing Record 15 of Set 3 | trujillo
# Processing Record 16 of Set 3 | sisimiut
# Processing Record 17 of Set 3 | colatina
# Processing Record 18 of Set 3 | haiku-pauwela
# Processing Record 19 of Set 3 | cabedelo
# Processing Record 20 of Set 3 | ujae
# Processing Record 21 of Set 3 | terrace
# Processing Record 22 of Set 3 | jerez de los caballeros
# Processing Record 23 of Set 3 | constantia
# Processing Record 24 of Set 3 | kingston
# Processing Record 25 of Set 3 | pisco
# Processing Record 26 of Set 3 | aoulef
# Processing Record 27 of Set 3 | cockburn town
# Processing Record 28 of Set 3 | dompu
# Processing Record 29 of Set 3 | west bay
# Processing Record 30 of Set 3 | keflavik
# Processing Record 31 of Set 3 | utrik
# Processing Record 32 of Set 3 | kavaratti
# Processing Record 33 of Set 3 | hobyo
# Processing Record 34 of Set 3 | ilhabela
# Processing Record 35 of Set 3 | lagos
# Processing Record 36 of Set 3 | playas
# Processing Record 37 of Set 3 | cam ranh
# Processing Record 38 of Set 3 | touros
# Processing Record 39 of Set 3 | motueka
# Processing Record 40 of Set 3 | igarka
# Processing Record 41 of Set 3 | shimoda
# Processing Record 42 of Set 3 | gebeit
# Processing Record 43 of Set 3 | namibe
# Processing Record 44 of Set 3 | mubende
# Processing Record 45 of Set 3 | acarau
# Processing Record 46 of Set 3 | tongliao
# Processing Record 47 of Set 3 | crane
# Processing Record 48 of Set 3 | morondava
# Processing Record 49 of Set 3 | hun
# Processing Record 0 of Set 4 | abu
# Processing Record 1 of Set 4 | muli
# Processing Record 2 of Set 4 | aitape
# Processing Record 3 of Set 4 | sitka
# Processing Record 4 of Set 4 | lijiang
# Processing Record 5 of Set 4 | guaratinga
# Processing Record 6 of Set 4 | kirensk
# Processing Record 7 of Set 4 | tralee
# Processing Record 8 of Set 4 | kawthoung
# City not found. Skipping...
# Processing Record 9 of Set 4 | kailua-kona
# Processing Record 10 of Set 4 | ulanhot
# Processing Record 11 of Set 4 | port elizabeth
# Processing Record 12 of Set 4 | nadym
# Processing Record 13 of Set 4 | susuman
# Processing Record 14 of Set 4 | juneau
# Processing Record 15 of Set 4 | ust-nera
# Processing Record 16 of Set 4 | vanino
# Processing Record 17 of Set 4 | ribeira grande
# Processing Record 18 of Set 4 | el fasher
# Processing Record 19 of Set 4 | katsuura
# Processing Record 20 of Set 4 | salalah
# Processing Record 21 of Set 4 | saint-pierre
# Processing Record 22 of Set 4 | narvik
# Processing Record 23 of Set 4 | sanica
# Processing Record 24 of Set 4 | alice springs
# Processing Record 25 of Set 4 | kingscliff
# Processing Record 26 of Set 4 | puerto san carlos
# City not found. Skipping...
# Processing Record 27 of Set 4 | ranchettes
# Processing Record 28 of Set 4 | juchipila
# Processing Record 29 of Set 4 | queenstown
# Processing Record 30 of Set 4 | amphoe sikhiu
# Processing Record 31 of Set 4 | kayangel
# Processing Record 32 of Set 4 | tsiombe
# Processing Record 33 of Set 4 | georgetown
# Processing Record 34 of Set 4 | avarua
# Processing Record 35 of Set 4 | birzebbuga
# Processing Record 36 of Set 4 | hamilton
# Processing Record 37 of Set 4 | luganville
# Processing Record 38 of Set 4 | ilgin
# Processing Record 39 of Set 4 | alpine
# Processing Record 40 of Set 4 | saldanha
# Processing Record 41 of Set 4 | severo-yeniseyskiy
# Processing Record 42 of Set 4 | deschutes river woods
# Processing Record 43 of Set 4 | asau
# Processing Record 44 of Set 4 | cidreira
# Processing Record 45 of Set 4 | yuzhno-kurilsk
# Processing Record 46 of Set 4 | at taraf
# Processing Record 47 of Set 4 | nungua
# Processing Record 48 of Set 4 | nar'yan-mar
# Processing Record 49 of Set 4 | tolanaro
# Processing Record 0 of Set 5 | altai
# Processing Record 1 of Set 5 | ahau
# City not found. Skipping...
# Processing Record 2 of Set 5 | okha
# Processing Record 3 of Set 5 | okhotsk
# Processing Record 4 of Set 5 | villa la angostura
# Processing Record 5 of Set 5 | isafjordur
# Processing Record 6 of Set 5 | kaedi
# Processing Record 7 of Set 5 | jiwani
# Processing Record 8 of Set 5 | east ballina
# Processing Record 9 of Set 5 | yoloten
# Processing Record 10 of Set 5 | corumba
# Processing Record 11 of Set 5 | boguchany
# Processing Record 12 of Set 5 | college
# Processing Record 13 of Set 5 | vorkuta
# Processing Record 14 of Set 5 | akureyri
# Processing Record 15 of Set 5 | bafoulabe
# Processing Record 16 of Set 5 | alaghsas
# Processing Record 17 of Set 5 | ilulissat
# Processing Record 18 of Set 5 | vorgashor
# Processing Record 19 of Set 5 | vuktyl
# Processing Record 20 of Set 5 | sao jose da coroa grande
# Processing Record 21 of Set 5 | kostanay
# Processing Record 22 of Set 5 | wailua homesteads
# Processing Record 23 of Set 5 | kargasok
# Processing Record 24 of Set 5 | selfoss
# Processing Record 25 of Set 5 | whitehorse
# Processing Record 26 of Set 5 | talnakh
# Processing Record 27 of Set 5 | lago da pedra
# Processing Record 28 of Set 5 | polyarnyy
# Processing Record 29 of Set 5 | gadzhiyevo
# Processing Record 30 of Set 5 | ak'ordat
# Processing Record 31 of Set 5 | puerto baquerizo moreno
# Processing Record 32 of Set 5 | mahibadhoo
# Processing Record 33 of Set 5 | beyneu
# Processing Record 34 of Set 5 | wonosobo
# Processing Record 35 of Set 5 | sydney mines
# Processing Record 36 of Set 5 | badger
# Processing Record 37 of Set 5 | saudarkrokur
# Processing Record 38 of Set 5 | san ignacio de velasco
# Processing Record 39 of Set 5 | la ronge
# Processing Record 40 of Set 5 | lebu
# Processing Record 41 of Set 5 | palmer
# Processing Record 42 of Set 5 | el rosario
# Processing Record 43 of Set 5 | iskateley
# Processing Record 44 of Set 5 | east london
# Processing Record 45 of Set 5 | northam
# Processing Record 46 of Set 5 | callao
# Processing Record 47 of Set 5 | camayenne
# Processing Record 48 of Set 5 | sainte-agathe-des-monts
# Processing Record 49 of Set 5 | sinjar
# Processing Record 0 of Set 6 | fiambala
# Processing Record 1 of Set 6 | tura
# Processing Record 2 of Set 6 | amqui
# Processing Record 3 of Set 6 | kegen
# Processing Record 4 of Set 6 | dowagiac
# Processing Record 5 of Set 6 | sandnessjoen
# Processing Record 6 of Set 6 | petropavlovsk-kamchatsky
# Processing Record 7 of Set 6 | thakhek
# Processing Record 8 of Set 6 | cole harbour
# Processing Record 9 of Set 6 | la sarre
# Processing Record 10 of Set 6 | poxoreo
# Processing Record 11 of Set 6 | arkadelphia
# Processing Record 12 of Set 6 | tranovaho
# City not found. Skipping...
# Processing Record 13 of Set 6 | serdar
# Processing Record 14 of Set 6 | malindi
# Processing Record 15 of Set 6 | palikir - national government center
# Processing Record 16 of Set 6 | vadso
# Processing Record 17 of Set 6 | hoek van holland
# Processing Record 18 of Set 6 | ina
# Processing Record 19 of Set 6 | san julian
# Processing Record 20 of Set 6 | vingt cinq
# City not found. Skipping...
# Processing Record 21 of Set 6 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 22 of Set 6 | musaffah
# Processing Record 23 of Set 6 | stettler
# Processing Record 24 of Set 6 | the pas
# Processing Record 25 of Set 6 | howard springs
# Processing Record 26 of Set 6 | necochea
# Processing Record 27 of Set 6 | staro nagorichane
# Processing Record 28 of Set 6 | sao joao da barra
# Processing Record 29 of Set 6 | al jawf
# Processing Record 30 of Set 6 | olgii
# City not found. Skipping...
# Processing Record 31 of Set 6 | arraial do cabo
# Processing Record 32 of Set 6 | nuuk
# Processing Record 33 of Set 6 | champerico
# Processing Record 34 of Set 6 | usogorsk
# Processing Record 35 of Set 6 | ciudad lazaro cardenas
# Processing Record 36 of Set 6 | mae hong son
# Processing Record 37 of Set 6 | cargados carajos
# City not found. Skipping...
# Processing Record 38 of Set 6 | suva
# Processing Record 39 of Set 6 | manga
# Processing Record 40 of Set 6 | booue
# Processing Record 41 of Set 6 | kutum
# Processing Record 42 of Set 6 | tumayr
# Processing Record 43 of Set 6 | watertown
# Processing Record 44 of Set 6 | hailin
# Processing Record 45 of Set 6 | acapulco de juarez
# Processing Record 46 of Set 6 | at taj
# Processing Record 47 of Set 6 | tamiahua
# Processing Record 48 of Set 6 | aldama
# Processing Record 49 of Set 6 | nagqu
# Processing Record 0 of Set 7 | nouadhibou
# Processing Record 1 of Set 7 | il'skiy
# Processing Record 2 of Set 7 | gidam
# Processing Record 3 of Set 7 | geraldton
# Processing Record 4 of Set 7 | pudozh
# Processing Record 5 of Set 7 | tarauaca
# Processing Record 6 of Set 7 | jayapura
# Processing Record 7 of Set 7 | el granada
# Processing Record 8 of Set 7 | bubaque
# Processing Record 9 of Set 7 | bengkulu
# Processing Record 10 of Set 7 | antigonish
# Processing Record 11 of Set 7 | pagar alam
# Processing Record 12 of Set 7 | galliano
# Processing Record 13 of Set 7 | brooks
# Processing Record 14 of Set 7 | enewetak
# Processing Record 15 of Set 7 | xilin hot
# Processing Record 16 of Set 7 | laojunmiao
# Processing Record 17 of Set 7 | tindouf
# Processing Record 18 of Set 7 | antsohihy
# Processing Record 19 of Set 7 | lapaha
# City not found. Skipping...
# Processing Record 20 of Set 7 | mont-laurier
# Processing Record 21 of Set 7 | naze
# Processing Record 22 of Set 7 | yilan
# Processing Record 23 of Set 7 | hilo
# Processing Record 24 of Set 7 | saipan
# Processing Record 25 of Set 7 | nicoya
# Processing Record 26 of Set 7 | kill devil hills
# Processing Record 27 of Set 7 | sur
# Processing Record 28 of Set 7 | ponta delgada
# Processing Record 29 of Set 7 | lerwick
# Processing Record 30 of Set 7 | pacific grove
# Processing Record 31 of Set 7 | nogliki
# Processing Record 32 of Set 7 | zaozersk
# Processing Record 33 of Set 7 | egilsstadir
# Processing Record 34 of Set 7 | mawu
# Processing Record 35 of Set 7 | midvagur
# Processing Record 36 of Set 7 | pontes e lacerda
# Processing Record 37 of Set 7 | san antonio de pale
# Processing Record 38 of Set 7 | chela
# Processing Record 39 of Set 7 | tanaina
# Processing Record 40 of Set 7 | olonkinbyen
# Processing Record 41 of Set 7 | nyergesujfalu
# Processing Record 42 of Set 7 | marsa alam
# Processing Record 43 of Set 7 | itoman
# Processing Record 44 of Set 7 | ad dabbah
# Processing Record 45 of Set 7 | prieska
# Processing Record 46 of Set 7 | island harbour
# Processing Record 47 of Set 7 | hadibu
# Processing Record 48 of Set 7 | mccook
# Processing Record 49 of Set 7 | pariaman
# Processing Record 0 of Set 8 | crucecita
# Processing Record 1 of Set 8 | broome
# Processing Record 2 of Set 8 | kipushi
# Processing Record 3 of Set 8 | inhambane
# Processing Record 4 of Set 8 | pallasovka
# Processing Record 5 of Set 8 | kalmunai
# Processing Record 6 of Set 8 | el galpon
# Processing Record 7 of Set 8 | roxas
# Processing Record 8 of Set 8 | raja
# Processing Record 9 of Set 8 | samamea
# City not found. Skipping...
# Processing Record 10 of Set 8 | chul'man
# Processing Record 11 of Set 8 | seven pagodas
# Processing Record 12 of Set 8 | mildura
# Processing Record 13 of Set 8 | bikenibeu village
# Processing Record 14 of Set 8 | fada
# Processing Record 15 of Set 8 | chernyshevskiy
# Processing Record 16 of Set 8 | myeik
# Processing Record 17 of Set 8 | new plymouth
# Processing Record 18 of Set 8 | sarmiento
# Processing Record 19 of Set 8 | atafu village
# Processing Record 20 of Set 8 | posto fiscal rolim de moura
# Processing Record 21 of Set 8 | plettenberg bay
# Processing Record 22 of Set 8 | daru
# Processing Record 23 of Set 8 | bestobe
# Processing Record 24 of Set 8 | shirgaon
# Processing Record 25 of Set 8 | new norfolk
# Processing Record 26 of Set 8 | la paz
# Processing Record 27 of Set 8 | isiolo
# Processing Record 28 of Set 8 | praia da vitoria
# Processing Record 29 of Set 8 | masvingo
# Processing Record 30 of Set 8 | uturoa
# Processing Record 31 of Set 8 | copsa mica
# Processing Record 32 of Set 8 | mariehamn
# Processing Record 33 of Set 8 | lethem
# Processing Record 34 of Set 8 | swift current
# Processing Record 35 of Set 8 | arvayheer
# Processing Record 36 of Set 8 | fortuna
# Processing Record 37 of Set 8 | santa cruz
# Processing Record 38 of Set 8 | zakynthos
# Processing Record 39 of Set 8 | mirny
# Processing Record 40 of Set 8 | khandyga
# Processing Record 41 of Set 8 | parkes
# Processing Record 42 of Set 8 | holbrook
# Processing Record 43 of Set 8 | dakhla
# Processing Record 44 of Set 8 | la malbaie
# Processing Record 45 of Set 8 | tadine
# Processing Record 46 of Set 8 | puerto lleras
# Processing Record 47 of Set 8 | portland
# Processing Record 48 of Set 8 | olyokminsk
# Processing Record 49 of Set 8 | yazykovo
# Processing Record 0 of Set 9 | lunino
# Processing Record 1 of Set 9 | lyantor
# Processing Record 2 of Set 9 | ghat
# Processing Record 3 of Set 9 | katsuren-haebaru
# Processing Record 4 of Set 9 | luderitz
# Processing Record 5 of Set 9 | carnarvon
# Processing Record 6 of Set 9 | dudinka
# Processing Record 7 of Set 9 | san jose village
# City not found. Skipping...
# Processing Record 8 of Set 9 | tommot
# Processing Record 9 of Set 9 | kristiansund
# Processing Record 10 of Set 9 | chaparral
# Processing Record 11 of Set 9 | howrah
# Processing Record 12 of Set 9 | mar del plata
# Processing Record 13 of Set 9 | mogoytuy
# Processing Record 14 of Set 9 | weno
# Processing Record 15 of Set 9 | malango
# Processing Record 16 of Set 9 | turkmenbasy
# Processing Record 17 of Set 9 | perry
# Processing Record 18 of Set 9 | balikpapan
# Processing Record 19 of Set 9 | kabalo
# Processing Record 20 of Set 9 | aripuana
# Processing Record 21 of Set 9 | codrington
# Processing Record 22 of Set 9 | weyburn
# Processing Record 23 of Set 9 | glace bay
# Processing Record 24 of Set 9 | yanchep
# Processing Record 25 of Set 9 | freetown
# Processing Record 26 of Set 9 | valentin gomez farias
# Processing Record 27 of Set 9 | sisophon
# Processing Record 28 of Set 9 | mount pearl
# Processing Record 29 of Set 9 | suomussalmi
# Processing Record 30 of Set 9 | pitimbu
# Processing Record 31 of Set 9 | al bawiti
# Processing Record 32 of Set 9 | trincomalee
# Processing Record 33 of Set 9 | cova figueira
# Processing Record 34 of Set 9 | coahuayana de hidalgo
# Processing Record 35 of Set 9 | ostersund
# Processing Record 36 of Set 9 | nishinoomote
# Processing Record 37 of Set 9 | bardai
# Processing Record 38 of Set 9 | port alfred
# Processing Record 39 of Set 9 | kulhudhuffushi
# Processing Record 40 of Set 9 | fort bragg
# Processing Record 41 of Set 9 | mucuri
# Processing Record 42 of Set 9 | marsh harbour
# Processing Record 43 of Set 9 | cururupu
# Processing Record 44 of Set 9 | sao lourenco do sul
# Processing Record 45 of Set 9 | alofi
# Processing Record 46 of Set 9 | boysun
# Processing Record 47 of Set 9 | odacho-oda
# Processing Record 48 of Set 9 | zhezqazghan
# Processing Record 49 of Set 9 | labrador city
# Processing Record 0 of Set 10 | aleksandrovsk-sakhalinskiy
# Processing Record 1 of Set 10 | santa terezinha
# Processing Record 2 of Set 10 | menongue
# Processing Record 3 of Set 10 | ola
# Processing Record 4 of Set 10 | sao tome
# Processing Record 5 of Set 10 | gstaad
# Processing Record 6 of Set 10 | puerto ayacucho
# Processing Record 7 of Set 10 | campechuela
# Processing Record 8 of Set 10 | mombetsu
# Processing Record 9 of Set 10 | tsengel
# Processing Record 10 of Set 10 | ust'-ilimsk
# Processing Record 11 of Set 10 | igrim
# Processing Record 12 of Set 10 | bamboo flat
# Processing Record 13 of Set 10 | newport
# Processing Record 14 of Set 10 | las terrenas
# Processing Record 15 of Set 10 | sola
# Processing Record 16 of Set 10 | ulbroka
# Processing Record 17 of Set 10 | siwa oasis
# Processing Record 18 of Set 10 | brainerd
# Processing Record 19 of Set 10 | launceston
# Processing Record 20 of Set 10 | spring creek
# Processing Record 21 of Set 10 | burgas
# Processing Record 22 of Set 10 | mugia
# Processing Record 23 of Set 10 | aegina
# Processing Record 24 of Set 10 | nyurba
# Processing Record 25 of Set 10 | flying fish cove
# Processing Record 26 of Set 10 | cidade velha
# Processing Record 27 of Set 10 | shangzhi
# Processing Record 28 of Set 10 | karagay
# Processing Record 29 of Set 10 | bodaybo
# Processing Record 30 of Set 10 | usinsk
# Processing Record 31 of Set 10 | labytnangi
# Processing Record 32 of Set 10 | niquelandia
# Processing Record 33 of Set 10 | al kharijah
# Processing Record 34 of Set 10 | andilamena
# Processing Record 35 of Set 10 | tamanrasset
# Processing Record 36 of Set 10 | ibotirama
# Processing Record 37 of Set 10 | kapuskasing
# Processing Record 38 of Set 10 | xishan
# Processing Record 39 of Set 10 | nemours
# Processing Record 40 of Set 10 | greymouth
# Processing Record 41 of Set 10 | vredendal
# Processing Record 42 of Set 10 | ponmana
# City not found. Skipping...
# Processing Record 43 of Set 10 | brookings
# Processing Record 44 of Set 10 | hayma'
# City not found. Skipping...
# Processing Record 45 of Set 10 | ginir
# Processing Record 46 of Set 10 | santa ana
# Processing Record 47 of Set 10 | zouerate
# Processing Record 48 of Set 10 | akure
# Processing Record 49 of Set 10 | merizo village
# Processing Record 0 of Set 11 | dryden
# Processing Record 1 of Set 11 | st. john's
# Processing Record 2 of Set 11 | westport
# Processing Record 3 of Set 11 | dalandzadgad
# Processing Record 4 of Set 11 | ar ruways
# Processing Record 5 of Set 11 | dabakala
# Processing Record 6 of Set 11 | nemuro
# Processing Record 7 of Set 11 | evanston
# Processing Record 8 of Set 11 | fougamou
# Processing Record 9 of Set 11 | riberalta
# Processing Record 10 of Set 11 | aykhal
# Processing Record 11 of Set 11 | bretten
# Processing Record 12 of Set 11 | magistral'nyy
# Processing Record 13 of Set 11 | jiaojiang
# Processing Record 14 of Set 11 | elkins
# Processing Record 15 of Set 11 | cabugao
# Processing Record 16 of Set 11 | agat village
# Processing Record 17 of Set 11 | walvis bay
# Processing Record 18 of Set 11 | mahebourg
# Processing Record 19 of Set 11 | ketchikan
# Processing Record 20 of Set 11 | sao vicente
# Processing Record 21 of Set 11 | owase
# Processing Record 22 of Set 11 | hasaki
# Processing Record 23 of Set 11 | umm kaddadah
# Processing Record 24 of Set 11 | bargara
# City not found. Skipping...
# Processing Record 25 of Set 11 | creel
# Processing Record 26 of Set 11 | mata-utu
# Processing Record 27 of Set 11 | pawni
# Processing Record 28 of Set 11 | tshabong
# Processing Record 29 of Set 11 | prado
# Processing Record 30 of Set 11 | corowa
# Processing Record 31 of Set 11 | hecun
# Processing Record 32 of Set 11 | heunghae
# Processing Record 33 of Set 11 | ardestan
# Processing Record 34 of Set 11 | ovruch
# Processing Record 35 of Set 11 | iskandar
# Processing Record 36 of Set 11 | kabompo
# Processing Record 37 of Set 11 | bogorodsk
# Processing Record 38 of Set 11 | lushun
# Processing Record 39 of Set 11 | grande prairie
# Processing Record 40 of Set 11 | fomboni
# Processing Record 41 of Set 11 | kuchinarai
# Processing Record 42 of Set 11 | kamaishi
# Processing Record 43 of Set 11 | qandala
# Processing Record 44 of Set 11 | faya-largeau
# Processing Record 45 of Set 11 | beledweyne
# Processing Record 46 of Set 11 | oranjemund
# Processing Record 47 of Set 11 | dolgorukovo
# Processing Record 48 of Set 11 | alenquer
# Processing Record 49 of Set 11 | angarsk
# Processing Record 0 of Set 12 | chonchi
# Processing Record 1 of Set 12 | mirabad
# Processing Record 2 of Set 12 | qina
# Processing Record 3 of Set 12 | isle of lewis
# City not found. Skipping...
# Processing Record 4 of Set 12 | magadan
# Processing Record 5 of Set 12 | am djarass
# City not found. Skipping...
# Processing Record 6 of Set 12 | prince rupert
# Processing Record 7 of Set 12 | lubang
# Processing Record 8 of Set 12 | mokhotlong
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          539
# Lat           539
# Lng           539
# Max Temp      539
# Humidity      539
# Cloudiness    539
# Wind Speed    539
# Country       539
# Date          539
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             iqaluit  63.7506  -68.5145    259.00        72          75
# 1   port-aux-francais -49.3500   70.2167    280.74        97         100
# 2  brisas de zicatela  15.8369  -97.0419    303.21        48          75
# 3           masterton -40.9597  175.6575    288.09        77           4
# 4             udachny  66.4167  112.4000    245.62        82         100
#
#    Wind Speed Country        Date
# 0        1.54      CA  1702492584
# 1       19.11      TF  1702492567
# 2        2.94      MX  1702492640
# 3        1.27      NZ  1702493072
# 4        4.80      RU  1702492584

# %%
# Export the City_Data into a csv
city_data_df.to_csv(r"C:\Users\conne\OneDrive\Desktop\NU-VIRT-DATA-PT-10-2023-U-LOLC\02-Homework\06-Python-APIs\Instructions\Starter_Code\output_data\cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv(r"C:\Users\conne\OneDrive\Desktop\NU-VIRT-DATA-PT-10-2023-U-LOLC\02-Homework\06-Python-APIs\Instructions\Starter_Code\output_data\cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                        City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                   iqaluit  63.7506  -68.5145    259.00        72
# 1         port-aux-francais -49.3500   70.2167    280.74        97
# 2        brisas de zicatela  15.8369  -97.0419    303.21        48
# 3                 masterton -40.9597  175.6575    288.09        77
# 4                   udachny  66.4167  112.4000    245.62        82
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                75        1.54      CA  1702492584
# 1               100       19.11      TF  1702492567
# 2                75        2.94      MX  1702492640
# 3                 4        1.27      NZ  1702493072
# 4               100        4.80      RU  1702492584

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolors="black")

plt.title("City Latitude vs. Temperature (12/09/2023)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

# Save the figure
plt.savefig(r"C:\Users\conne\OneDrive\Desktop\NU-VIRT-DATA-PT-10-2023-U-LOLC\02-Homework\06-Python-APIs\Instructions\Starter_Code\output_data\Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE

plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolors="black")

plt.title("City Latitude vs. Humidity (12/09/2023)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig(r"C:\Users\conne\OneDrive\Desktop\NU-VIRT-DATA-PT-10-2023-U-LOLC\02-Homework\06-Python-APIs\Instructions\Starter_Code\output_data\Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolors="black")

plt.title("City Latitude vs. Cloudiness (12/09/2023)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig(r"C:\Users\conne\OneDrive\Desktop\NU-VIRT-DATA-PT-10-2023-U-LOLC\02-Homework\06-Python-APIs\Instructions\Starter_Code\output_data\Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolors="black")

plt.title("City Latitude vs. Wind Speed (12/09/2023)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig(r"C:\Users\conne\OneDrive\Desktop\NU-VIRT-DATA-PT-10-2023-U-LOLC\02-Homework\06-Python-APIs\Instructions\Starter_Code\output_data\Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

def plot_linear_regression(x_values, y_values, title, text_corordinates):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y =" + str(round(slope,2)) + "x + " + str(round(intercept, 2))
    
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.xlabel("Latitude")
    plt.ylabel(title)
    print(f"The r-value is: {rvalue**2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

northern_hemi_df.head()
# Out:
#                        City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                   iqaluit  63.7506  -68.5145    259.00        72
# 2        brisas de zicatela  15.8369  -97.0419    303.21        48
# 4                   udachny  66.4167  112.4000    245.62        82
# 9                   shalqar  47.8333   59.6000    261.04        32
# 10                  klyuchi  52.2667   79.1667    249.73        84
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                75        1.54      CA  1702492584
# 2                75        2.94      MX  1702492640
# 4               100        4.80      RU  1702492584
# 9               100        9.95      KZ  1702493073
# 10               83        2.52      RU  1702492591

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        port-aux-francais -49.3500   70.2167    280.74        97         100
# 3                masterton -40.9597  175.6575    288.09        77           4
# 5        riachao das neves -11.7461  -44.9100    310.02        22           4
# 6                grytviken -54.2811  -36.5092    276.39        97         100
# 7               mahavelona -17.6848   49.5087    300.14        85          88
#
#          Wind Speed Country        Date
# City_ID
# 1             19.11      TF  1702492567
# 3              1.27      NZ  1702493072
# 5              2.07      BR  1702493072
# 6              3.28      GS  1702492566
# 7              1.36      MG  1702493072

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# Define your X and Y values

x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp", (0,0))

# plt.text(0, 0, f"y = {round(slope, 2)}x + {round(intercept, 2)}", bbox=dict(facecolor="white", edgecolor="black", pad=5))
# Out:
# The r-value is: 0.7151521229090637

# %%
# Linear regression on Southern Hemisphere

x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp", (0,0))
# Out:
# The r-value is: 0.4495177362695968

# %% [markdown]
# # **Discussion about the linear relationship: It is clear the max temperature increases as you get closer to 0 latitude in the northern and southern hemisphere. The plots show the temperatures in cities across both hemispheres.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity", (0,0))
# Out:
# The r-value is: 0.19495558842745248

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity", (0,0))
# Out:
# The r-value is: 0.008016071168502214

# %% [markdown]
# # **Discussion about the linear relationship: The two plots show the humidity for multiple cities across the nothern and southern hemispheres. While it appears that the further away you move from 0 latitude the more humid it gets in the northern hemisphere, both plots fail to produce any significant correlation based on their R-Values.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness", (0,0))
# Out:
# The r-value is: 0.10246651124114439

# %%
# Southern Hemisphere

x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness", (0,0))
# Out:
# The r-value is: 0.009148487769070958

# %% [markdown]
# # **Discussion about the linear relationship: The plots show the level of cloud different cities experience across the northern and southern hemispheres. The data is very scattered and there does not appear to be a correlation between these two variables.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed", (0,0))
# Out:
# The r-value is: 0.011352465571313175

# %%
# Southern Hemisphere

x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed", (0,0))
# Out:
# The r-value is: 0.14254748813073853

# %% [markdown]
# # **Discussion about the linear relationship: The two plots show the wind speed of multiple cities across the northern and southern hemisphere. There does not appear to be any correlation between the two variables.
